# %%
# 셀 1: 필수 패키지 설치
# !pip install selenium
# !apt-get update
# !apt install -y chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0, '/usr/lib/chromium-browser/chromedriver')
# Out:
# Collecting selenium
#   Downloading selenium-4.34.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting urllib3~=2.5.0 (from urllib3[socks]~=2.5.0->selenium)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.7.9)
# Requirement already satisfied: typing_extensions~=4.14.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.34.2-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 66.6 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 31.8 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 9.5 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# Successfully installed outcome-1.3.0.post0 selenium-4.34.2 trio-0.30.0 trio-websocket-0.12.2 urllib3-2.5.0 wsproto-1.2.0
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,103 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,757 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,420 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,266 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,569 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,963 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,106 kB]
# Fetched 26.6 MB in 5s (5,745 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 libudev1 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 snapd
#   squashfs-tools systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 8 newly installed, 0 to remove and 41 not upgraded.
# Need to get 30.3 MB of archives.
# After this operation, 123 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.16 [76.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.16 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.67.1+22.04 [27.8 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [2,308 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Fetched 30.3 MB in 3s (9,862 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.16_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.16) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.16) ...
# Selecting previously unselected package udev.
# (Reading database ... 126481 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.16_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.16) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.67.1+22.04_amd64.deb ...
# Unpacking snapd (2.67.1+22.04) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.16) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.67.1+22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 126710 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Processing triggers for udev (249.11-0ubuntu3.16) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
def scroll_through_all_lis(driver):
    """모든 li 요소를 순차적으로 스크롤하여 lazy loading을 유도"""
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # 모든 li를 대상으로 하나씩 스크롤
        lis = driver.find_elements("css selector", "section.CommonPcListUnitProduct_list_unit_product__AeuOT ul[role='list'] > li")
        for li in lis:
            try:
                driver.execute_script("arguments[0].scrollIntoView(true);", li)
                time.sleep(0.3)  # 로딩 대기
            except:
                continue

        # 새 높이를 확인해 더 로딩되는지 판단
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# %%
# 셀 2: Selenium 설정 및 데이터 수집
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# ✅ 크롤링 대상 URL 리스트
urls = [
    "https://www.lge.co.kr/category/wash-tower",
    "https://www.lge.co.kr/category/wash-combo",
    "https://www.lge.co.kr/category/washing-machines",
    "https://www.lge.co.kr/category/dryers"
]

# ✅ Chrome 옵션 설정 (Colab 환경)
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# ✅ 크롬 드라이버 실행
driver = webdriver.Chrome(options=options)

# ✅ 스크래핑 함수 정의
def scrape_data_ec_product(url):
    driver.get(url)
    time.sleep(3)  # 페이지 로딩 대기

    scroll_through_all_lis(driver)  # ✅ 실제 li를 보이게 함

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    section = soup.find('section', class_="CommonPcListUnitProduct_list_unit_product__AeuOT")
    data_list = []

    if section:
        ul = section.find('ul', role='list')
        if ul:
            lis = ul.find_all('li')
            for li in lis:
                data = li.get('data-ec-product')
                if data:
                    data_list.append(data)
    return data_list

# ✅ 전체 URL 대상 스크래핑 수행
all_data = {}
for url in urls:
    print(f"크롤링 중: {url}")
    data = scrape_data_ec_product(url)
    all_data[url] = data
    print(f"수집된 항목 수: {len(data)}")
# Out:
# 크롤링 중: https://www.lge.co.kr/category/wash-tower
# 수집된 항목 수: 89
# 크롤링 중: https://www.lge.co.kr/category/wash-combo
# 수집된 항목 수: 26
# 크롤링 중: https://www.lge.co.kr/category/washing-machines
# 수집된 항목 수: 266
# 크롤링 중: https://www.lge.co.kr/category/dryers
# 수집된 항목 수: 102

# %%
# 셀 3: 결과 확인
import json

# ✅ 결과를 JSON 형식으로 출력
for url, items in all_data.items():
    print(f"\n📌 URL: {url}")
    for item in items:
        print(json.loads(item))  # JSON 문자열을 dict로 변환하여 출력
# Out:
# 📌 URL: https://www.lge.co.kr/category/wash-tower
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09942859', 'model_sku': 'WL21WDU.AKOR', 'model_gubun': '일반제품', 'base_price': '3,100,000', 'price': '2,715,600', 'discounted_price': '3,100,000', 'grand_price': '3,990,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09942827', 'model_sku': 'WL21EGZU.AKOR', 'model_gubun': '일반제품', 'base_price': '3,260,000', 'price': '2,864,400', 'discounted_price': '3,260,000', 'grand_price': '4,290,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09900826', 'model_sku': 'W20WHN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,550,000', 'price': '2,259,900', 'discounted_price': '2,550,000', 'grand_price': '3,390,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09916826', 'model_sku': 'W20WZNM.AKOR', 'model_gubun': '일반제품', 'base_price': '3,000,000', 'price': '2,622,600', 'discounted_price': '3,000,000', 'grand_price': '3,350,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09159852', 'model_sku': 'W20EGZ.AKOR', 'model_gubun': '일반제품', 'base_price': '2,850,000', 'price': '2,538,900', 'discounted_price': '2,850,000', 'grand_price': '3,890,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283848', 'model_sku': 'WL22KDU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,290,000', 'price': '3,822,300', 'discounted_price': '4,290,000', 'grand_price': '4,762,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283849', 'model_sku': 'WL22WDU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,290,000', 'price': '3,822,300', 'discounted_price': '4,290,000', 'grand_price': '4,762,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283864', 'model_sku': 'WL22YMZU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,984,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283854', 'model_sku': 'WL22GMZU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,984,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283839', 'model_sku': 'WL22EGHU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,500,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283861', 'model_sku': 'WL22MYZU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,984,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283857', 'model_sku': 'WL22EMZU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,984,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트', 'model_id': 'MD09907827', 'model_sku': 'W10BN.AKOR', 'model_gubun': '일반제품', 'base_price': '1,940,000', 'price': '1,711,200', 'discounted_price': '1,940,000', 'grand_price': '2,690,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트', 'model_id': 'MD09907826', 'model_sku': 'W10BHN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,030,000', 'price': '1,776,300', 'discounted_price': '2,030,000', 'grand_price': '2,790,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트', 'model_id': 'MD09465826', 'model_sku': 'W10WAN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,070,000', 'price': '1,813,500', 'discounted_price': '2,070,000', 'grand_price': '2,490,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09765846', 'model_sku': 'W20WANQ.AKOR', 'model_gubun': '일반제품', 'base_price': '2,600,000', 'price': '2,306,400', 'discounted_price': '2,600,000', 'grand_price': '3,340,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트', 'model_id': 'MD09387826', 'model_sku': 'W10EGN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,050,000', 'price': '1,794,900', 'discounted_price': '2,050,000', 'grand_price': '2,690,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10594826', 'model_sku': 'W2520WZM.AKOR', 'model_gubun': '일반제품', 'base_price': '3,490,000', 'price': '3,078,300', 'discounted_price': '3,490,000', 'grand_price': '3,495,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 워시타워', 'model_id': 'MD09092832', 'model_sku': 'W20WD.AKOR', 'model_gubun': '일반제품', 'base_price': '2,780,000', 'price': '2,473,800', 'discounted_price': '2,780,000', 'grand_price': '3,590,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 워시타워', 'model_id': 'MD09155834', 'model_sku': 'W20WAN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,572,000', 'price': '2,280,400', 'discounted_price': '2,572,000', 'grand_price': '3,340,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09154846', 'model_sku': 'W20EEAN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,940,000', 'price': '2,622,600', 'discounted_price': '2,940,000', 'grand_price': '3,740,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09942860', 'model_sku': 'WL21GGN.AKOR', 'model_gubun': '일반제품', 'base_price': '4,140,000', 'price': '3,682,800', 'discounted_price': '4,140,000', 'grand_price': '4,595,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09843839', 'model_sku': 'W21EGZ.AKOR', 'model_gubun': '일반제품', 'base_price': '3,140,000', 'price': '2,752,800', 'discounted_price': '3,140,000', 'grand_price': '4,190,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09843840', 'model_sku': 'W21EEZ.AKOR', 'model_gubun': '일반제품', 'base_price': '4,190,000', 'price': '3,729,300', 'discounted_price': '4,190,000', 'grand_price': '4,651,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 AI 오브제컬렉션 워시타워', 'model_id': 'MD10575826', 'model_sku': 'WA2525EGZF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,890,000', 'price': '4,280,300', 'discounted_price': '4,890,000', 'grand_price': '5,330,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 AI 오브제컬렉션 워시타워', 'model_id': 'MD10575828', 'model_sku': 'WA2525IIHF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,890,000', 'price': '4,280,300', 'discounted_price': '4,890,000', 'grand_price': '5,330,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 AI 오브제컬렉션 워시타워', 'model_id': 'MD10576826', 'model_sku': 'WA2525GGZF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,890,000', 'price': '4,280,300', 'discounted_price': '4,890,000', 'grand_price': '5,330,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10407827', 'model_sku': 'W21GEAM.AKOR', 'model_gubun': '일반제품', 'base_price': '4,140,000', 'price': '3,682,800', 'discounted_price': '4,140,000', 'grand_price': '4,145,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10594827', 'model_sku': 'W2321GEAM.AKOR', 'model_gubun': '일반제품', 'base_price': '3,190,000', 'price': '2,799,300', 'discounted_price': '3,190,000', 'grand_price': '3,890,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD10283844', 'model_sku': 'WL22MYHU.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,500,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09916827', 'model_sku': 'W20WHNM.AKOR', 'model_gubun': '일반제품', 'base_price': '3,350,000', 'price': '2,948,100', 'discounted_price': '3,350,000', 'grand_price': '3,990,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 디오스 오브제컬렉션 매직스페이스', 'model_id': 'MD10555846', 'model_sku': '20WN-S84ME3.AKOR', 'model_gubun': '일반제품', 'base_price': '4,170,000', 'price': '3,710,700', 'discounted_price': '4,170,000', 'grand_price': '5,780,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 디오스 오브제컬렉션 매직스페이스', 'model_id': 'MD10555855', 'model_sku': '20EG-S84ME3.AKOR', 'model_gubun': '일반제품', 'base_price': '4,540,000', 'price': '4,054,800', 'discounted_price': '4,540,000', 'grand_price': '6,280,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430856', 'model_sku': 'W20EGZ-5S4.AKOR', 'model_gubun': '일반제품', 'base_price': '4,140,000', 'price': '3,682,800', 'discounted_price': '4,140,000', 'grand_price': '5,380,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 디오스 오브제컬렉션 베이직 냉장고', 'model_id': 'MD10555843', 'model_sku': '20WN-S84MW1.AKOR', 'model_gubun': '일반제품', 'base_price': '3,820,000', 'price': '3,385,200', 'discounted_price': '3,820,000', 'grand_price': '4,970,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트+ LG 모던엣지 냉장고 오브제컬렉션', 'model_id': 'MD10555860', 'model_sku': '10WN-Q33MH3.AKOR', 'model_gubun': '일반제품', 'base_price': '2,800,000', 'price': '2,492,400', 'discounted_price': '2,800,000', 'grand_price': '3,590,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430854', 'model_sku': 'WL21WW-5S4.AKOR', 'model_gubun': '일반제품', 'base_price': '4,320,000', 'price': '3,850,200', 'discounted_price': '4,320,000', 'grand_price': '5,480,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10540837', 'model_sku': '1EG-G52.AKOR', 'model_gubun': '일반제품', 'base_price': '4,760,000', 'price': '4,259,400', 'discounted_price': '4,760,000', 'grand_price': '6,180,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434828', 'model_sku': 'W20WD-5B4.AKOR', 'model_gubun': '일반제품', 'base_price': '4,010,000', 'price': '3,561,900', 'discounted_price': '4,010,000', 'grand_price': '5,130,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10540836', 'model_sku': '2EG-G52.AKOR', 'model_gubun': '일반제품', 'base_price': '4,460,000', 'price': '3,980,400', 'discounted_price': '4,460,000', 'grand_price': '5,780,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540844', 'model_sku': '2EG-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '3,860,000', 'price': '3,422,400', 'discounted_price': '3,860,000', 'grand_price': '5,400,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10540834', 'model_sku': '1WU-G52.AKOR', 'model_gubun': '일반제품', 'base_price': '4,640,000', 'price': '4,147,800', 'discounted_price': '4,640,000', 'grand_price': '5,880,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541843', 'model_sku': '2EG-G52-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '5,460,000', 'price': '4,910,400', 'discounted_price': '5,460,000', 'grand_price': '7,290,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541847', 'model_sku': '1EG-G52-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '5,760,000', 'price': '5,189,400', 'discounted_price': '5,760,000', 'grand_price': '7,690,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540840', 'model_sku': '1WU-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '4,040,000', 'price': '3,589,800', 'discounted_price': '4,040,000', 'grand_price': '5,500,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540848', 'model_sku': '1EG-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '4,160,000', 'price': '3,701,400', 'discounted_price': '4,160,000', 'grand_price': '5,800,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430864', 'model_sku': 'W20WD-5M5.AKOR', 'model_gubun': '일반제품', 'base_price': '4,300,000', 'price': '3,831,600', 'discounted_price': '4,300,000', 'grand_price': '5,480,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434832', 'model_sku': 'W21WAM-5B4.AKOR', 'model_gubun': '일반제품', 'base_price': '5,030,000', 'price': '4,510,500', 'discounted_price': '5,030,000', 'grand_price': '5,380,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541831', 'model_sku': '1WU-G52-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '5,640,000', 'price': '5,077,800', 'discounted_price': '5,640,000', 'grand_price': '7,390,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430866', 'model_sku': 'W20WANQ-5M5.AKOR', 'model_gubun': '일반제품', 'base_price': '4,040,000', 'price': '3,589,800', 'discounted_price': '4,040,000', 'grand_price': '4,990,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430867', 'model_sku': 'W20WAN-5M5.AKOR', 'model_gubun': '일반제품', 'base_price': '4,020,000', 'price': '3,571,200', 'discounted_price': '4,020,000', 'grand_price': '5,230,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10539829', 'model_sku': '1EG-20W.AKOR', 'model_gubun': '일반제품', 'base_price': '4,310,000', 'price': '3,840,900', 'discounted_price': '4,310,000', 'grand_price': '5,450,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430863', 'model_sku': 'W21GEAM-5B4.AKOR', 'model_gubun': '일반제품', 'base_price': '5,330,000', 'price': '4,789,500', 'discounted_price': '5,330,000', 'grand_price': '5,680,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10430865', 'model_sku': 'W20GEAN-5B4.AKOR', 'model_gubun': '일반제품', 'base_price': '4,210,000', 'price': '3,747,900', 'discounted_price': '4,210,000', 'grand_price': '4,990,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10433846', 'model_sku': 'W21WAM-5SH.AKOR', 'model_gubun': '일반제품', 'base_price': '5,690,000', 'price': '5,124,300', 'discounted_price': '5,690,000', 'grand_price': '6,080,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434826', 'model_sku': 'W21GEAM-5SH.AKOR', 'model_gubun': '일반제품', 'base_price': '5,990,000', 'price': '5,403,300', 'discounted_price': '5,990,000', 'grand_price': '6,380,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434830', 'model_sku': 'W21GEAM-5M5.AKOR', 'model_gubun': '일반제품', 'base_price': '5,620,000', 'price': '5,059,200', 'discounted_price': '5,620,000', 'grand_price': '6,030,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434831', 'model_sku': 'W21WAM-5M5.AKOR', 'model_gubun': '일반제품', 'base_price': '5,330,000', 'price': '4,789,500', 'discounted_price': '5,330,000', 'grand_price': '5,730,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 디오스 오브제컬렉션 STEM 베이직 냉장고', 'model_id': 'MD10555857', 'model_sku': '20EG-M85GB0.AKOR', 'model_gubun': '일반제품', 'base_price': '6,570,000', 'price': '5,942,700', 'discounted_price': '6,570,000', 'grand_price': '7,690,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 AI 오브제컬렉션 워시타워', 'model_id': 'MD10601837', 'model_sku': 'WA2525GMZF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,890,000', 'price': '4,890,000', 'discounted_price': '4,890,000', 'grand_price': '5,330,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워', 'model_id': 'MD09765845', 'model_sku': 'W20VANQ.AKOR', 'model_gubun': '일반제품', 'base_price': '2,360,000', 'price': '2,360,000', 'discounted_price': '2,360,000', 'grand_price': '3,700,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541827', 'model_sku': '1WU-M8H-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '6,043,000', 'price': '6,043,000', 'discounted_price': '6,043,000', 'grand_price': '7,740,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541836', 'model_sku': '2EG-M8H-48H.AKOR', 'model_gubun': '일반제품', 'base_price': '5,995,000', 'price': '5,995,000', 'discounted_price': '5,995,000', 'grand_price': '7,640,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541837', 'model_sku': '2EG-M8H-48W.AKOR', 'model_gubun': '일반제품', 'base_price': '5,849,000', 'price': '5,849,000', 'discounted_price': '5,849,000', 'grand_price': '7,640,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541838', 'model_sku': '2EG-M8H-27H.AKOR', 'model_gubun': '일반제품', 'base_price': '5,801,000', 'price': '5,801,000', 'discounted_price': '5,801,000', 'grand_price': '7,440,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541839', 'model_sku': '2EG-M8H-20W.AKOR', 'model_gubun': '일반제품', 'base_price': '5,655,000', 'price': '5,655,000', 'discounted_price': '5,655,000', 'grand_price': '7,290,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10540830', 'model_sku': '1WU-M8H.AKOR', 'model_gubun': '일반제품', 'base_price': '4,705,000', 'price': '4,705,000', 'discounted_price': '4,705,000', 'grand_price': '6,230,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10539828', 'model_sku': '1EG-M8H.AKOR', 'model_gubun': '일반제품', 'base_price': '5,005,000', 'price': '5,005,000', 'discounted_price': '5,005,000', 'grand_price': '6,530,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10539830', 'model_sku': '1EG-M8H-20W.AKOR', 'model_gubun': '일반제품', 'base_price': '6,150,000', 'price': '6,150,000', 'discounted_price': '6,150,000', 'grand_price': '7,690,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10434827', 'model_sku': 'W20WD-5SH.AKOR', 'model_gubun': '일반제품', 'base_price': '4,390,000', 'price': '4,390,000', 'discounted_price': '4,390,000', 'grand_price': '5,830,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 컴팩트 + LG 스타일러', 'model_id': 'MD10079826', 'model_sku': 'W10WAN-3JHW.AKOR', 'model_gubun': '일반제품', 'base_price': '2,690,000', 'price': '2,690,000', 'discounted_price': '2,690,000', 'grand_price': '3,580,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러', 'model_id': 'MD10540835', 'model_sku': '2EG-M8H.AKOR', 'model_gubun': '일반제품', 'base_price': '4,511,000', 'price': '4,511,000', 'discounted_price': '4,511,000', 'grand_price': '6,130,000', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541830', 'model_sku': '1WU-G52-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541832', 'model_sku': '1WU-G52-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541834', 'model_sku': '1WU-G52-20W.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541840', 'model_sku': '2EG-G52-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541844', 'model_sku': '2EG-G52-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541845', 'model_sku': '2EG-G52-20W.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541846', 'model_sku': '1EG-G52-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541848', 'model_sku': '1EG-G52-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541849', 'model_sku': '1EG-G52-20W.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540838', 'model_sku': '1WU-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540841', 'model_sku': '1WU-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540842', 'model_sku': '1WU-20W.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540847', 'model_sku': '1EG-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540849', 'model_sku': '1EG-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540843', 'model_sku': '2EG-48H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540845', 'model_sku': '2EG-27H.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시타워 + LG 코드제로 A9S', 'model_id': 'MD10540846', 'model_sku': '2EG-20W.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시타워/워시타워 세트', 'ct_id': 'CT50000110', 'model_super_category': '생활가전', 'model_category': '워시타워', 'model_sub_category': '워시타워 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
#
# 📌 URL: https://www.lge.co.kr/category/wash-combo
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10335844', 'model_sku': 'FH25KA.AKOR', 'model_gubun': '일반제품', 'base_price': '3,700,000', 'price': '3,273,600', 'discounted_price': '3,700,000', 'grand_price': '4,440,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10480828', 'model_sku': 'FH25ESE.AKOR', 'model_gubun': '일반제품', 'base_price': '4,440,000', 'price': '3,961,800', 'discounted_price': '4,440,000', 'grand_price': '4,540,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10335835', 'model_sku': 'FH25EAE.AKOR', 'model_gubun': '일반제품', 'base_price': '4,250,000', 'price': '3,785,100', 'discounted_price': '4,250,000', 'grand_price': '4,490,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG SIGNATURE 세탁건조기', 'model_id': 'MD10330834', 'model_sku': 'FH25LMTH.AKOR', 'model_gubun': '일반제품', 'base_price': '6,900,000', 'price': '6,900,000', 'discounted_price': '6,900,000', 'grand_price': '0', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10335846', 'model_sku': 'FH25WA.AKOR', 'model_gubun': '일반제품', 'base_price': '3,800,000', 'price': '3,366,600', 'discounted_price': '3,800,000', 'grand_price': '4,340,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10335843', 'model_sku': 'FH25GAG.AKOR', 'model_gubun': '일반제품', 'base_price': '4,250,000', 'price': '3,785,100', 'discounted_price': '4,250,000', 'grand_price': '4,490,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10335845', 'model_sku': 'FH25VA.AKOR', 'model_gubun': '일반제품', 'base_price': '3,940,000', 'price': '3,496,800', 'discounted_price': '3,940,000', 'grand_price': '4,390,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10491829', 'model_sku': 'FH25KAX.CKOR', 'model_gubun': '일반제품', 'base_price': '3,650,000', 'price': '2,927,100', 'discounted_price': '3,650,000', 'grand_price': '5,040,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10548827', 'model_sku': 'FH25ESEFX.CKOR', 'model_gubun': '일반제품', 'base_price': '5,090,000', 'price': '4,266,300', 'discounted_price': '5,090,000', 'grand_price': '5,190,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10467832', 'model_sku': 'FH25EAEX.CKOR', 'model_gubun': '일반제품', 'base_price': '4,690,000', 'price': '3,894,300', 'discounted_price': '4,690,000', 'grand_price': '5,140,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10467831', 'model_sku': 'FH25GAGX.CKOR', 'model_gubun': '일반제품', 'base_price': '4,690,000', 'price': '3,894,300', 'discounted_price': '4,690,000', 'grand_price': '5,340,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10467829', 'model_sku': 'FH25WAX.CKOR', 'model_gubun': '일반제품', 'base_price': '3,770,000', 'price': '3,038,700', 'discounted_price': '3,770,000', 'grand_price': '4,840,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 미니워시', 'model_id': 'MD10491830', 'model_sku': 'FH25VAX.CKOR', 'model_gubun': '일반제품', 'base_price': '3,920,000', 'price': '3,178,200', 'discounted_price': '3,920,000', 'grand_price': '4,940,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 키높이 수납함', 'model_id': 'MD10343835', 'model_sku': 'FH25EAEF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,008,300', 'discounted_price': '4,490,000', 'grand_price': '4,690,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + 키높이 수납함', 'model_id': 'MD10548832', 'model_sku': 'FH25ESEF.AKOR', 'model_gubun': '일반제품', 'base_price': '4,540,000', 'price': '4,054,800', 'discounted_price': '4,540,000', 'grand_price': '4,740,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러', 'model_id': 'MD10540862', 'model_sku': 'KAX-G52.CKOR', 'model_gubun': '일반제품', 'base_price': '5,170,000', 'price': '4,640,700', 'discounted_price': '5,170,000', 'grand_price': '6,930,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 코드제로 A9S', 'model_id': 'MD10540863', 'model_sku': 'KAX-48W.CKOR', 'model_gubun': '일반제품', 'base_price': '4,570,000', 'price': '4,082,700', 'discounted_price': '4,570,000', 'grand_price': '6,550,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10541851', 'model_sku': 'KAX-M8H-48W.CKOR', 'model_gubun': '일반제품', 'base_price': '7,013,000', 'price': '6,354,700', 'discounted_price': '7,013,000', 'grand_price': '8,790,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10540859', 'model_sku': 'KAX-G52-48W.CKOR', 'model_gubun': '일반제품', 'base_price': '6,170,000', 'price': '5,570,700', 'discounted_price': '6,170,000', 'grand_price': '8,440,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러', 'model_id': 'MD10478827', 'model_sku': 'KAX-M8H.CKOR', 'model_gubun': '일반제품', 'base_price': '5,675,000', 'price': '5,110,400', 'discounted_price': '5,675,000', 'grand_price': '7,280,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보', 'model_id': 'MD10341827', 'model_sku': 'FH25GA.AKOR', 'model_gubun': '일반제품', 'base_price': '4,490,000', 'price': '4,490,000', 'discounted_price': '4,490,000', 'grand_price': '4,940,000', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10540858', 'model_sku': 'KAX-G52-48H.CKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10540860', 'model_sku': 'KAX-G52-27H.CKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 스타일러 + LG 코드제로 A9S', 'model_id': 'MD10540861', 'model_sku': 'KAX-G52-20W.CKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 워시콤보 + LG 코드제로 A9S', 'model_id': 'MD10540864', 'model_sku': 'KAX-27H.CKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/워시콤보/워시콤보 세트', 'ct_id': 'CT50250001', 'model_super_category': '생활가전', 'model_category': '워시콤보', 'model_sub_category': '워시콤보 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# ...
# {'model_name': 'LG 트롬 + 건조기', 'model_id': 'MD10193835', 'model_sku': 'F24WDLP-9WW.AKOR', 'model_gubun': '일반제품', 'base_price': '2,350,000', 'price': '2,073,900', 'discounted_price': '2,350,000', 'grand_price': '3,090,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 건조기', 'model_id': 'MD10214833', 'model_sku': 'RD21ESC.AKOR', 'model_gubun': '일반제품', 'base_price': '2,140,000', 'price': '2,140,000', 'discounted_price': '2,140,000', 'grand_price': '2,330,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 건조기', 'model_id': 'MD09529826', 'model_sku': 'RD20WN.AKOR', 'model_gubun': '일반제품', 'base_price': '1,718,000', 'price': '1,718,000', 'discounted_price': '1,718,000', 'grand_price': '1,790,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 건조기 + 스태킹키트', 'model_id': 'MD09990865', 'model_sku': 'RD20WN-KW.AKOR', 'model_gubun': '일반제품', 'base_price': '1,790,000', 'price': '1,790,000', 'discounted_price': '1,790,000', 'grand_price': '1,987,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 건조기', 'model_id': 'MD10373832', 'model_sku': 'RD21EN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,040,000', 'price': '2,040,000', 'discounted_price': '2,040,000', 'grand_price': '2,045,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 트윈워시 + 건조기', 'model_id': 'MD10051842', 'model_sku': 'FX23ENEX-EE.AKOR', 'model_gubun': '일반제품', 'base_price': '3,090,000', 'price': '3,090,000', 'discounted_price': '3,090,000', 'grand_price': '4,390,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10051851', 'model_sku': 'FX23GNG-GNG.AKOR', 'model_gubun': '일반제품', 'base_price': '2,590,000', 'price': '2,590,000', 'discounted_price': '2,590,000', 'grand_price': '3,680,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193866', 'model_sku': 'KX3ENE-1ESE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,890,000', 'price': '2,890,000', 'discounted_price': '2,890,000', 'grand_price': '3,930,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 건조기 + LG 통돌이 세탁기', 'model_id': 'MD10193828', 'model_sku': 'RG9WN-T7WX3.AKOR', 'model_gubun': '일반제품', 'base_price': '1,640,000', 'price': '1,640,000', 'discounted_price': '1,640,000', 'grand_price': '2,190,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193868', 'model_sku': 'KX3GNG-1ESE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,830,000', 'price': '2,830,000', 'discounted_price': '2,830,000', 'grand_price': '3,930,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10051848', 'model_sku': 'KX23GNG-ENE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,750,000', 'price': '2,750,000', 'discounted_price': '2,750,000', 'grand_price': '3,680,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 건조기 + LG 통돌이 세탁기', 'model_id': 'MD10193830', 'model_sku': 'RG8WN-T7WX3.AKOR', 'model_gubun': '일반제품', 'base_price': '1,590,000', 'price': '1,590,000', 'discounted_price': '1,590,000', 'grand_price': '2,140,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10322838', 'model_sku': 'KG21WN-G8NW.AKOR', 'model_gubun': '일반제품', 'base_price': '2,290,000', 'price': '2,290,000', 'discounted_price': '2,290,000', 'grand_price': '2,800,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10059844', 'model_sku': 'KFG19VN-9VN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,100,000', 'price': '2,100,000', 'discounted_price': '2,100,000', 'grand_price': '2,625,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066826', 'model_sku': 'KFG21GN-9GN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,630,000', 'price': '2,630,000', 'discounted_price': '2,630,000', 'grand_price': '2,898,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066827', 'model_sku': 'KFG21GN-9EN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,650,000', 'price': '2,650,000', 'discounted_price': '2,650,000', 'grand_price': '2,898,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066829', 'model_sku': 'KFG21GN-8EN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,690,000', 'price': '2,690,000', 'discounted_price': '2,690,000', 'grand_price': '3,390,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066830', 'model_sku': 'KFG21EN-9GN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,600,000', 'price': '2,600,000', 'discounted_price': '2,600,000', 'grand_price': '2,898,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066831', 'model_sku': 'KFG21EN-9EN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,320,000', 'price': '2,320,000', 'discounted_price': '2,320,000', 'grand_price': '2,898,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066833', 'model_sku': 'KFG21EN-8EN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,690,000', 'price': '2,690,000', 'discounted_price': '2,690,000', 'grand_price': '3,390,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066834', 'model_sku': 'KFG21VN-8VN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,420,000', 'price': '2,420,000', 'discounted_price': '2,420,000', 'grand_price': '2,671,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066846', 'model_sku': 'KFG19WN-9WN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,220,000', 'price': '2,220,000', 'discounted_price': '2,220,000', 'grand_price': '2,534,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193862', 'model_sku': 'KX4ENE-1ESE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,500,000', 'price': '2,500,000', 'discounted_price': '2,500,000', 'grand_price': '3,930,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193864', 'model_sku': 'KX4GNG-1ESE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,590,000', 'price': '2,590,000', 'discounted_price': '2,590,000', 'grand_price': '3,930,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 건조기 + LG 스타일러', 'model_id': 'MD10079832', 'model_sku': 'RG18WN-3JHW.AKOR', 'model_gubun': '일반제품', 'base_price': '1,890,000', 'price': '1,890,000', 'discounted_price': '1,890,000', 'grand_price': '2,630,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193873', 'model_sku': 'KX23KN-20WN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,490,000', 'price': '2,490,000', 'discounted_price': '2,490,000', 'grand_price': '3,580,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10213827', 'model_sku': 'KX23VN-2VN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,850,000', 'price': '2,850,000', 'discounted_price': '2,850,000', 'grand_price': '3,540,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10051849', 'model_sku': 'KX23ENE-GNG.AKOR', 'model_gubun': '일반제품', 'base_price': '2,810,000', 'price': '2,810,000', 'discounted_price': '2,810,000', 'grand_price': '3,680,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10051850', 'model_sku': 'FX23ENE-ENE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,750,000', 'price': '2,750,000', 'discounted_price': '2,750,000', 'grand_price': '3,680,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 키높이 수납함', 'model_id': 'MD10048838', 'model_sku': 'FX23GNGF-GG.AKOR', 'model_gubun': '일반제품', 'base_price': '2,890,000', 'price': '2,890,000', 'discounted_price': '2,890,000', 'grand_price': '3,840,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 키높이 수납함', 'model_id': 'MD10048839', 'model_sku': 'FX23ENEF-EE.AKOR', 'model_gubun': '일반제품', 'base_price': '2,690,000', 'price': '2,690,000', 'discounted_price': '2,690,000', 'grand_price': '3,840,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 트윈워시 + 건조기', 'model_id': 'MD10051841', 'model_sku': 'FX23GNGX-GG.AKOR', 'model_gubun': '일반제품', 'base_price': '3,090,000', 'price': '3,090,000', 'discounted_price': '3,090,000', 'grand_price': '4,390,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193876', 'model_sku': 'KX23WNA-2WN.AKOR', 'model_gubun': '일반제품', 'base_price': '2,790,000', 'price': '2,790,000', 'discounted_price': '2,790,000', 'grand_price': '3,430,000', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'Y'}
# {'model_name': 'LG 트롬 건조기', 'model_id': 'MD09194830', 'model_sku': 'RH19KTAN.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10066837', 'model_sku': 'KFG19GN-9GN.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10226834', 'model_sku': 'FX24ENE-GNG.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'N'}
# {'model_name': 'LG 트롬 오브제컬렉션 + 건조기 + 스태킹키트', 'model_id': 'MD10193860', 'model_sku': 'KX24WN-2WNA.AKOR', 'model_gubun': '일반제품', 'brand': 'LG', 'category': '생활가전/의류건조기/건조기 세트', 'ct_id': 'CT50000107', 'model_super_category': '생활가전', 'model_category': '의류건조기', 'model_sub_category': '건조기 세트', 'delivery_badge': 'N', 'price_badge': 'N'}

# %%
driver = webdriver.Chrome(options=options)

def get_product_links(url):
    driver.get(url)
    time.sleep(3)  # 페이지 로딩 대기

    scroll_through_all_lis(driver)  # ✅ 실제 li를 보이게 함

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    links = []
    divs = soup.find_all('div', class_="CommonPcListUnitProduct_img_wrap__4haVO")
    for div in divs:
        a_tag = div.find('a')
        if a_tag and a_tag.has_attr('href'):
            links.append(a_tag['href'])
    return links

def get_base_url(url):
    # /category가 있다면 그 앞까지만 남김
    idx = url.find('/category')
    if idx != -1:
        return url[:idx]
    else:
        # /category가 없으면 전체 url
        return url

all_product_links = {}

for url in urls:
    print(f"크롤링 중: {url}")
    product_links = get_product_links(url)
    print(f"수집된 링크 수: {len(product_links)}")

    # /category 뒤로 다 삭제한 base_url 만들기
    base_url = get_base_url(url)

    full_links = []
    for link in product_links:
        if link.startswith('/'):
            full_url = base_url + link
        else:
            full_url = base_url + '/' + link
        full_links.append(full_url)

    all_product_links[url] = full_links

# 결과 출력
print("\n수집된 전체 상품 상세페이지 URL 리스트 (카테고리별):")
for url, links in all_product_links.items():
    print(f"\n📌 카테고리 URL: {url}")
    for link in links:
        print(link)
# Out:
# 크롤링 중: https://www.lge.co.kr/category/wash-tower
# 수집된 링크 수: 89
# 크롤링 중: https://www.lge.co.kr/category/wash-combo
# 수집된 링크 수: 26
# 크롤링 중: https://www.lge.co.kr/category/washing-machines
# 수집된 링크 수: 266
# 크롤링 중: https://www.lge.co.kr/category/dryers
# 수집된 링크 수: 102
#
# 수집된 전체 상품 상세페이지 URL 리스트 (카테고리별):
#     main_area = soup.find('div', class_='pdp-visual-area hidden-sm', id='desktop_summary_gallery')
#     if main_area:
#         inner = main_area.find('div', class_='pdp-visual-inner default')
#         if inner:
#             for img in inner.find_all('img'):
#                 if img.has_attr('src'):
#                     main_imgs.append(img['src'])
#                 elif img.has_attr('data-src'):
#                     main_imgs.append(img['data-src'])

#     # 2. 썸네일 이미지
#     thumb_area = soup.find('div', class_='pdp-thumbnail-nav')
#     if thumb_area:
#         for img in thumb_area.find_all('img'):
#             if img.has_attr('src'):
#                 thumb_imgs.append(img['src'])
#             elif img.has_attr('data-src'):
#                 thumb_imgs.append(img['data-src'])

#     return main_imgs, thumb_imgs


# for url, links in all_product_links.items():
#     print(f"\n📌 카테고리 URL: {url}")
#     for link in links:
#         print(f"  상세페이지: {link}")
#         driver.get(link)
#         time.sleep(2)
#         soup = BeautifulSoup(driver.page_source, 'html.parser')
#         main_imgs, thumb_imgs = extract_desktop_gallery_imgs(soup)
#         print("메인 갤러리 이미지 src:", main_imgs)
#         print("썸네일 이미지 src:", thumb_imgs)
# Out:
# 📌 카테고리 URL: https://www.lge.co.kr/category/wash-tower
#   상세페이지: https://www.lge.co.kr/wash-tower/wl21wdu
# 메인 갤러리 이미지 src: ['/kr/images/wash-tower/md09942859/gallery/medium-interior01.jpg']
# 썸네일 이미지 src: ['/kr/images/wash-tower/md09942859/gallery/small-interior01.jpg', '/kr/images/wash-tower/md09942859/gallery/small01.jpg', '/kr/images/wash-tower/md09942859/gallery/small02.jpg', '/kr/images/wash-tower/md09942859/gallery/small03.jpg', '/kr/images/wash-tower/md09942859/gallery/small04.jpg', '/kr/images/wash-tower/md09942859/gallery/small05.jpg']
#   상세페이지: https://www.lge.co.kr/wash-tower/wl21egzu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-6-3293479001.py in <cell line: 0>()
#      35     for link in links:
#      36         print(f"  상세페이지: {link}")
# ---> 37         driver.get(link)
#      38         time.sleep(2)
#      39         soup = BeautifulSoup(driver.page_source, 'html.parser')
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     477         >>> driver.get("https://example.com")
#     478         """
# --> 479         self.execute(Command.GET, {"url": url})
#     480
#     481     @property
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     449                 params["sessionId"] = self.session_id
#     450
# --> 451         response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     452
#     453         if response:
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     402         trimmed = self._trim_large_entries(params)
#     403         LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404         return self._request(command_info[0], url, body=data)
#     405
#     406     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     426
#     427         if self._client_config.keep_alive:
# --> 428             response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429             statuscode = response.status
#     430         else:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     141             )
#     142         else:
# --> 143             return self.request_encode_body(
#     144                 method, url, fields=fields, headers=headers, **urlopen_kw
#     145             )
#
# /usr/local/lib/python3.11/dist-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     276         extra_kw.update(urlopen_kw)
#     277
# --> 278         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     457             response = conn.urlopen(method, url, **kw)
#     458         else:
# --> 459             response = conn.urlopen(method, u.request_uri, **kw)
#     460
#     461         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
driver = webdriver.Chrome(options=options)

BASE_URL = "https://www.lge.co.kr"

def get_soup(driver, url, scroll=False):
    """
    Selenium 드라이버로 url 접속 후 BeautifulSoup 객체 반환
    """
    driver.get(url)
    time.sleep(2)
    # 필요시 스크롤 등 추가 동작
    return BeautifulSoup(driver.page_source, 'html.parser')

def make_absolute_url(src, base_url=BASE_URL):
    """
    이미지 src가 절대경로가 아니면 base_url을 붙여 절대경로로 변환
    """
    if src.startswith("http"):
        return src
    return base_url + src

def extract_images(soup):
    """
    상세페이지에서 대표 이미지 src 추출 (절대경로로 반환)
    """
    images = []
    div = soup.find('div', class_="slide-content pdp-visual ui_carousel_list ui_static draggable")
    if div:
        ul = div.find('ul', class_="slide-track pdp-visual-list ui_carousel_track ui_static")
        if ul:
            for li in ul.find_all('li'):
                li_class = ' '.join(li.get('class', []))
                if (li_class == "slide-conts ui_carousel_slide default thumbnail img_square" or
                    li_class == "slide-conts ui_carousel_slide default thumbnail img_square ui_carousel_current on"):
                    a_tag = li.find('a')
                    if a_tag:
                        img_tag = a_tag.find('img')
                        if img_tag and img_tag.has_attr('src'):
                            img_src = make_absolute_url(img_tag['src'])
                            images.append({'img_src': img_src})
    return images

def extract_specs(soup):
    """
    상세페이지에서 스펙 정보 추출
    """
    specs = []
    prod_spec_div = soup.find('div', class_='prod-spec-detail')
    if prod_spec_div:
        box_div = prod_spec_div.find('div', class_='box')
        spec_title = box_div.find('h3', class_='tit').get_text(strip=True) if box_div and box_div.find('h3', class_='tit') else ''
        spec_info_div = prod_spec_div.find('div', class_='spec-info-list')
        if spec_info_div:
            ul_tag = spec_info_div.find('ul')
            if ul_tag:
                for li in ul_tag.find_all('li'):
                    dl_tag = li.find('dl')
                    if dl_tag:
                        dt_tag = dl_tag.find('dt')
                        dd_tag = dl_tag.find('dd')
                        dt_text = ''
                        dt_btn_data = None
                        if dt_tag:
                            button_tag = dt_tag.find('button')
                            if button_tag and button_tag.has_attr('data-spec-description'):
                                dt_btn_data = button_tag['data-spec-description']
                            dt_text = dt_tag.get_text(strip=True)
                        dd_text = dd_tag.get_text(strip=True) if dd_tag else ''
                        specs.append({
                            'spec_title': spec_title,
                            'dt': dt_text,
                            'dd': dd_text,
                            'dt_button_data_spec_description': dt_btn_data
                        })
    return specs

def get_product_detail_info(driver, detail_url):
    """
    상세페이지에서 이미지와 스펙 정보를 모두 추출
    """
    soup = get_soup(driver, detail_url, scroll=False)
    return {
        'images': extract_images(soup),
        'specs': extract_specs(soup)
    }

# --- 크롤링 실행 예시 ---

all_product_details = {}

for category_url, detail_urls in all_product_links.items():
    print(f"\n📂 카테고리: {category_url}")
    details_list = []
    for detail_url in detail_urls:
        info = get_product_detail_info(driver, detail_url)
        details_list.append({
            'detail_url': detail_url,
            'images': info['images'],
            'specs': info['specs']
        })
    all_product_details[category_url] = details_list

# 결과 출력
for category_url, details_list in all_product_details.items():
    print(f"\n=== 카테고리: {category_url}")
    for detail in details_list:
        print(f"\n상품 상세 URL: {detail['detail_url']}")
        print("이미지 정보:")
        for img in detail['images']:
            print(f"  - src: {img['img_src']}")
        print("스펙 정보:")
        for spec in detail['specs']:
            print(f"  - [{spec['dt']}] {spec['dd']} (button data: {spec['dt_button_data_spec_description']})")

# driver.quit()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines
button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/k4ng1se-5sh
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433882/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433882/gallery/medium02.jpg
# 스펙 정보:
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/k4ne2ng-5b4
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433883/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433883/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/k4ng2ne-5m5
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433884/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10433884/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 그린 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kg21wn-g8nw
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10322838/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10322838/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kx25vr-21vs-akor2
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10487828/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10487828/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 25 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg19vn-9vn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10059844/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10059844/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 19 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg21gn-9gn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066826/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066826/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg21gn-9en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066827/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066827/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg21gn-8en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066829/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066829/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg21en-9gn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066830/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066830/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/washing-machines/kfg21en-9en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066831/gallery/medium02.jpg
# ...
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21gn-9en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066827/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066827/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21gn-8en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066829/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066829/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21en-9gn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066830/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066830/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21en-9en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066831/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066831/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21en-8en
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066833/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066833/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg21vn-8vn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066834/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066834/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 21 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg19wn-9wn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066846/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066846/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 19 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx4ene-1ese
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193862/gallery/medium03.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193862/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx4gng-1ese
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193864/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193864/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 그린 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/rg18wn-3jhw
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/dryers/md10079832/gallery/medium01.jpg
# 스펙 정보:
#   - [건조 용량 (kg)] 18 (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx23kn-20wn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193873/gallery/medium03.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193873/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx23vn-2vn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10213827/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10213827/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx23ene-gng
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10051849/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10051849/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/fx23ene-ene
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10051850/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10051850/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/fx23gngf-gg
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10048838/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 그린 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/fx23enef-ee
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10048839/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/fx23gngx-gg
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10051841/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 그린 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx23wna-2wn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193876/gallery/medium03.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193876/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 23 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 릴리 화이트 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/rh19ktan
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/dryers/md09194830/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/dryers/md09194830/gallery/medium02.jpg
# 스펙 정보:
#   - [색상] 블랙 스테인리스 (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kfg19gn-9gn
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066837/gallery/medium02.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10066837/gallery/medium01.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 19 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/fx24ene-gng
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10226834/gallery/medium01.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10226834/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 네이처 베이지 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
#
# 상품 상세 URL: https://www.lge.co.kr/dryers/kx24wn-2wna
# 이미지 정보:
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193860/gallery/medium03.jpg
#   - src: https://www.lge.co.kr/kr/images/washing-machines/md10193860/gallery/medium02.jpg
# 스펙 정보:
#   - [세탁 용량 (kg)] 24 (button data: 1인 기준 일주일치 빨랫감은 평균 4~5kg* 으로 구성원 수와 사용패턴을 고려하여 용량 선택에 참고 하실 수 있습니다.
#
# [가구 유형별 추천 용량]
#
# 1-2인
# · 트롬 : 12~15kg
# · 통돌이 세탁기: 10~12kg
#
# 1인 가구 일주일 치 세탁물이 4kg임을 감안해 10kg 초반 작은 용량을 추천드립니다.
#
# 2-3인
# · 트롬 : 21~23kg
# · 통돌이 세탁기: 15~16kg
#
# 겉옷이나 속옷을 나눠 세탁하거나 땀 흘린 운동복, 반려동물 장난감 등 별도 세탁물이 많다면 기존 트롬에 미니워시를 추가해도 좋습니다.
#
# 3인 이상
# · 트롬 : 21~25kg
# · 통돌이 세탁기: 20~24kg
# · 트롬 트윈워시: 28~29kg
#
# 드럼 방식은 세탁시 낙차를 이용한 여유 공간이 필요해 통돌이 세탁기보다 세탁 용량을 20~30% 크게 잡으면 좋습니다.)
#   - [색상] 릴리 화이트 (button data: None)
#   - [크기 (WxHxD)] 700 x 990 x 830 mm (button data: None)
#   - [도어 열림 시 크기 (WxHxD)] 700 x 990 x 1,410 mm (button data: None)
